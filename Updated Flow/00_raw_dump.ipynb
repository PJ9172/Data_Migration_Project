# %% [markdown]
# # Connection String

# %%
jdbc_url = "jdbc:postgresql://0.tcp.in.ngrok.io:26324/demo"

username = "postgres"
password = "root"

driver = "org.postgresql.Driver"

# %% [markdown]
# # Customer Table Creation

# %%
customers_df = (
    spark.read
    .format("jdbc")
    .option("url", jdbc_url)
    .option("dbtable", "public.customers")
    .option("user", username)
    .option("password", password)
    .option("driver", driver)
    .load()
)
display(customers_df)

customers_df.write.format("delta").mode("overWrite").saveAsTable("migration.raw.customers")

# %% [markdown]
# # Orders Table Creation

# %%
orders_df = (
    spark.read
    .format("jdbc")
    .option("url", jdbc_url)
    .option("dbtable", "public.orders")
    .option("user", username)
    .option("password", password)
    .option("driver", driver)
    .load()
)
display(orders_df)

orders_df.write.format("delta").mode("overWrite").saveAsTable("migration.raw.orders")

# %% [markdown]
# # Products Table Creation

# %%
products_df = (
    spark.read
    .format("jdbc")
    .option("url", jdbc_url)
    .option("dbtable", "public.products")
    .option("user", username)
    .option("password", password)
    .option("driver", driver)
    .load()
)
display(products_df)

products_df.write.format("delta").mode("overWrite").saveAsTable("migration.raw.products")
